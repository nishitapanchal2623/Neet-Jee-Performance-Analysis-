# %% [markdown]
# # Project 1: NEET-JEE Performance Analysis
#
# ## Phase 3: Univariate Exploratory Data Analysis (EDA)
#
# ### Objective
#
# The objective of this notebook is to analyze each variable independently to understand its distribution, frequency, variability, and overall characteristics. Univariate analysis provides valuable insights into individual features before exploring relationships between variables.

# %%
#Import Required Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# Plot Style
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## Load the Clean Dataset
#
# The cleaned dataset generated during the data preprocessing phase is loaded for exploratory data analysis. Using the cleaned dataset ensures that the analysis is performed on validated and high-quality data.

# %%
## Load the Clean Dataset
df = pd.read_csv("../data/cleaned/College_Admission_Cleaned.csv")

print("Dataset Loaded Successfully!")
print(f"Rows : {df.shape[0]}")
print(f"Columns : {df.shape[1]}")
# Out:
# Dataset Loaded Successfully!
# Rows : 25000
# Columns : 13

# %% [markdown]
# ### Observation
#
# The cleaned dataset has been loaded successfully and is ready for exploratory data analysis. Since the dataset has already been validated during the data cleaning phase, all subsequent visualizations and statistical analyses will be performed on this dataset.

# %% [markdown]
# # Numerical Variable Analysis
#
# The numerical variables are analyzed individually to understand their distribution, central tendency, spread, and potential outliers. Histograms and box plots are used to visualize the characteristics of each feature.

# %% [markdown]
# ## Distribution of Student Age

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    data=df,
    x="age",
    bins=4,
    kde=True,
    color="steelblue",
    edgecolor="black"
)

plt.title("Distribution of Student Age", fontsize=16, fontweight="bold")
plt.xlabel("Age")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Observation
#
# The age distribution indicates that the dataset includes students aged between **17 and 20 years**. The frequency of students is nearly uniform across all age groups, suggesting a well-balanced dataset with no age-related bias. No outliers or abnormal age values are observed, confirming that the age feature is suitable for further exploratory analysis.

# %% [markdown]
# ## Distribution of Entrance Examination Score

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    data=df,
    x="entrance_score",
    bins=30,
    kde=True,
    color="darkorange",
    edgecolor="black"
)

plt.title("Distribution of Entrance Examination Score", fontsize=16, fontweight="bold")
plt.xlabel("Entrance Score")
plt.ylabel("Number of Students")

plt.tight_layout()
plt.savefig("../figures/age_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Box Plot of Entrance Examination Score

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    x=df["entrance_score"],
    color="skyblue"
)

plt.title("Box Plot of Entrance Examination Score", fontsize=16, fontweight="bold")
plt.xlabel("Entrance Score")

plt.tight_layout()

plt.savefig("../figures/entrance_score_boxplot.png",
            dpi=300,
            bbox_inches="tight")

plt.show()

# %%
df["entrance_score"].describe()
# Out:
# count    25000.000000
# mean        77.879760
# std        120.356125
# min          0.000000
# 25%          0.000000
# 50%         20.000000
# 75%        126.000000
# max        634.000000
# Name: entrance_score, dtype: float64

# %% [markdown]
# ### Observation
#
# The distribution of entrance examination scores is highly positively skewed. Most students have relatively low entrance scores, while a small proportion of students achieved exceptionally high scores, resulting in a long right tail. The box plot reveals numerous high-value outliers, which appear to be valid observations rather than data quality issues. The mean entrance score (77.88) is substantially higher than the median score (20), further confirming the presence of a right-skewed distribution.

# %% [markdown]
# ## Distribution of Board Percentage

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    data=df,
    x="board_percentage",
    bins=20,
    kde=True,
    color="mediumseagreen",
    edgecolor="black"
)

plt.title("Distribution of Board Percentage", fontsize=16, fontweight="bold")
plt.xlabel("Board Percentage")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../figures/board_percentage_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Box Plot of Board Percentage

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    x=df["board_percentage"],
    color="lightgreen"
)

plt.title("Box Plot of Board Percentage", fontsize=16, fontweight="bold")
plt.xlabel("Board Percentage")

plt.tight_layout()

plt.savefig(
    "../figures/board_percentage_boxplot.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
df["board_percentage"].describe()
# Out:
# count    25000.000000
# mean        75.028014
# std         14.438767
# min         50.440000
# 25%         62.550000
# 50%         75.070000
# 75%         87.640000
# max         99.530000
# Name: board_percentage, dtype: float64

# %% [markdown]
# ### Observation
#
# The board percentage distribution is approximately symmetric, with scores ranging from 50.44% to 99.53%. The mean (75.03%) and median (75.07%) are nearly identical, indicating a balanced distribution without significant skewness. The box plot shows no extreme outliers, suggesting that students' board examination performance is consistently distributed across the dataset.

# %% [markdown]
# ## Distribution of Admission Probability

# %%
plt.figure(figsize=(10,6))

sns.histplot(
    data=df,
    x="admission_probability",
    bins=20,
    kde=True,
    color="royalblue",
    edgecolor="black"
)

plt.title("Distribution of Admission Probability", fontsize=16, fontweight="bold")
plt.xlabel("Admission Probability")
plt.ylabel("Number of Students")

plt.tight_layout()

plt.savefig(
    "../figures/admission_probability_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Box Plot of Admission Probability

# %%
plt.figure(figsize=(10,6))

sns.boxplot(
    x=df["admission_probability"],
    color="cornflowerblue"
)

plt.title("Box Plot of Admission Probability", fontsize=16, fontweight="bold")
plt.xlabel("Admission Probability")

plt.tight_layout()

plt.savefig(
    "../figures/admission_probability_boxplot.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The admission probability is distributed approximately in a bell-shaped pattern, with most students having admission probabilities between 0.20 and 0.45. The box plot indicates no significant outliers, and the distribution appears relatively balanced. This suggests that the predicted admission probabilities are well distributed across the student population without extreme variations.

# %% [markdown]
# ## Summary of Numerical Variable Analysis
#
# | Feature | Distribution | Outliers | Key Finding |
# |---------|--------------|----------|-------------|
# | Age | Uniform | No | Students are evenly distributed between 17–20 years. |
# | Entrance Score | Right-Skewed | Yes | Majority of students have low scores, with several high-score outliers. |
# | Board Percentage | Approximately Symmetric | No | Academic performance is consistently distributed. |
# | Admission Probability | Approximately Bell-Shaped | No | Most admission probabilities lie between 0.20 and 0.45. |

# %% [markdown]
# # Categorical Variable Analysis
#
# Categorical variables are analyzed to understand the frequency distribution of different categories. Count plots help visualize the number of observations within each category, providing insights into the composition of the dataset.

# %% [markdown]
# ## Distribution of Student Category

# %%
plt.figure(figsize=(9,5))

ax = sns.countplot(
    data=df,
    x="category",
    hue="category",
    palette="Set3",
    legend=False
)

plt.title("Distribution of Student Category", fontsize=16, fontweight="bold")
plt.xlabel("Category")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.tight_layout()

plt.savefig(
    "../figures/category_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The student category distribution is well balanced across all reservation groups, including General, EWS, SC, OBC, and ST. Each category contains approximately 5,000 students, with only minor differences in frequency. This balanced representation reduces category-related sampling bias and supports fair comparative analysis throughout the project.

# %% [markdown]
# ## Distribution of Entrance Examination

# %%
plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x="entrance_exam",
    hue="entrance_exam",
    palette="Pastel1",
    legend=False
)

plt.title("Distribution of Entrance Examination", fontsize=16, fontweight="bold")
plt.xlabel("Entrance Examination")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.tight_layout()

plt.savefig(
    "../figures/entrance_exam_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The entrance examination distribution shows that the largest recorded category is `none`, with 11,288 students, followed by CET with 10,433 students. NEET accounts for 2,034 students, while JEE has the smallest representation with 1,245 students. Overall, the dataset contains substantially more observations under the `none` and CET categories than under NEET and JEE. Therefore, comparisons involving NEET and JEE should consider their relatively smaller sample sizes.

# %% [markdown]
# ## Distribution of Admission Status

# %%
plt.figure(figsize=(8, 5))

ax = sns.countplot(
    data=df,
    x="admission_status",
    hue="admission_status",
    palette="Set2",
    legend=False
)

plt.title("Distribution of Admission Status", fontsize=16, fontweight="bold")
plt.xlabel("Admission Status")
plt.ylabel("Number of Students")

for container in ax.containers:
    ax.bar_label(container)

plt.tight_layout()

plt.savefig(
    "../figures/admission_status_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Entrance Examination-wise Performance
#
# This analysis compares the average entrance examination score across JEE, NEET, and CET candidates to identify differences in examination performance.

# %%
exam_performance = (
    df[df["entrance_exam"].isin(["jee", "neet", "cet"])]
    .groupby("entrance_exam")["entrance_score"]
    .agg(["count", "mean", "median", "std"])
    .round(2)
)

exam_performance
# Out:
#                count    mean  median     std
# entrance_exam
# cet            10433   99.97   101.0   58.08
# jee             1245  146.50   147.0   84.55
# neet            2034  354.78   357.0  201.65

# %%
plt.figure(figsize=(8, 5))

ax = sns.barplot(
    data=exam_performance.reset_index(),
    x="entrance_exam",
    y="mean",
    hue="entrance_exam",
    palette="Set2",
    legend=False
)

plt.title("Average Entrance Score by Examination", fontsize=16, fontweight="bold")
plt.xlabel("Entrance Examination")
plt.ylabel("Average Entrance Score")

for container in ax.containers:
    ax.bar_label(container, fmt="%.2f")

plt.tight_layout()

plt.savefig(
    "../figures/average_entrance_score_by_exam.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The average entrance score differs considerably across the three examination categories. NEET has the highest mean score (354.78), followed by JEE (146.50) and CET (99.97). The median scores show the same ordering. NEET also has the highest standard deviation (201.65), indicating greater variation in its recorded scores. However, direct comparison of raw scores across examinations should be interpreted cautiously because different examinations may use different scoring scales.

# %% [markdown]
# ## Admission Probability by Entrance Examination

# %%
exam_admission = (
    df[df["entrance_exam"].isin(["jee", "neet", "cet"])]
    .groupby("entrance_exam")["admission_probability"]
    .agg(["count", "mean", "median", "std"])
    .round(3)
)

exam_admission
# Out:
#                count   mean  median    std
# entrance_exam
# cet            10433  0.339   0.340  0.126
# jee             1245  0.372   0.372  0.134
# neet            2034  0.505   0.515  0.166

# %%
plt.figure(figsize=(8, 5))

ax = sns.barplot(
    data=exam_admission.reset_index(),
    x="entrance_exam",
    y="mean",
    hue="entrance_exam",
    palette="Set2",
    legend=False
)

plt.title("Average Admission Probability by Examination",
          fontsize=16, fontweight="bold")
plt.xlabel("Entrance Examination")
plt.ylabel("Average Admission Probability")

for container in ax.containers:
    ax.bar_label(container, fmt="%.3f")

plt.tight_layout()

plt.savefig(
    "../figures/average_admission_probability_by_exam.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The average admission probability varies across entrance examination categories. NEET has the highest average admission probability of 0.505, followed by JEE at 0.372 and CET at 0.339. The median values follow the same pattern. Within this dataset, NEET candidates therefore have the highest recorded admission probability on average, while CET candidates have the lowest. These results indicate an association between entrance examination category and admission probability, but they do not establish a causal relationship.

# %% [markdown]
# ## Relationship Between Entrance Score and Admission Probability

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="entrance_score",
    y="admission_probability",
    alpha=0.4
)

sns.regplot(
    data=df,
    x="entrance_score",
    y="admission_probability",
    scatter=False
)

plt.title(
    "Entrance Score vs Admission Probability",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Entrance Score")
plt.ylabel("Admission Probability")

plt.tight_layout()

plt.savefig(
    "../figures/entrance_score_vs_admission_probability.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
correlation = df["entrance_score"].corr(
    df["admission_probability"]
)

print("Correlation:", round(correlation, 3))
# Out:
# Correlation: 0.554

# %% [markdown]
# ### Observation
#
# The scatter plot shows a positive relationship between entrance score and admission probability. The regression line indicates that admission probability generally increases as entrance score increases. The Pearson correlation coefficient is 0.554, indicating a moderate positive linear relationship between the two variables. Therefore, higher entrance scores are generally associated with higher admission probabilities in this dataset.

# %% [markdown]
# ## Relationship Between Board Percentage and Admission Probability

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="board_percentage",
    y="admission_probability",
    alpha=0.4
)

sns.regplot(
    data=df,
    x="board_percentage",
    y="admission_probability",
    scatter=False
)

plt.title(
    "Board Percentage vs Admission Probability",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Board Percentage")
plt.ylabel("Admission Probability")

plt.tight_layout()

plt.savefig(
    "../figures/board_percentage_vs_admission_probability.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
correlation_board = df["board_percentage"].corr(
    df["admission_probability"]
)

print("Correlation:", round(correlation_board, 3))
# Out:
# Correlation: 0.727

# %% [markdown]
# ### Observation
#
# The scatter plot shows a clear positive relationship between board percentage and admission probability. The Pearson correlation coefficient is 0.727, indicating a strong positive linear association between the two variables. As board percentage increases, admission probability generally tends to increase. Compared with entrance score (r = 0.554), board percentage shows a stronger linear association with admission probability in this dataset.

# %% [markdown]
# ## Category-wise Entrance Score Performance

# %%
category_performance = (
    df.groupby("category")["entrance_score"]
      .agg(["count", "mean", "median", "std"])
      .round(2)
)

category_performance
# Out:
#           count   mean  median     std
# category
# ews        4933  78.81    16.0  124.35
# general    4963  76.76    22.0  116.44
# obc        5022  77.49    21.0  119.30
# sc         5001  75.55    15.0  118.99
# st         5081  80.75    25.0  122.52

# %%
plt.figure(figsize=(9, 5))

ax = sns.barplot(
    data=category_performance.reset_index(),
    x="category",
    y="mean",
    hue="category",
    palette="Set2",
    legend=False
)

plt.title(
    "Average Entrance Score by Category",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Category")
plt.ylabel("Average Entrance Score")

for container in ax.containers:
    ax.bar_label(container, fmt="%.2f")

plt.tight_layout()

plt.savefig(
    "../figures/category_vs_entrance_score.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The average entrance scores across student categories are relatively close, ranging from 75.55 for SC to 80.75 for ST. ST has the highest average entrance score, while SC has the lowest. However, the relatively large standard deviations within all categories indicate substantial variation in entrance scores among students. The median scores are considerably lower than the corresponding means, reflecting the skewed distribution of entrance scores observed earlier.

# %% [markdown]
# ## Category-wise Admission Probability

# %%
category_admission = (
    df.groupby("category")["admission_probability"]
      .agg(["count", "mean", "median", "std"])
      .round(3)
)

category_admission
# Out:
#           count   mean  median    std
# category
# ews        4933  0.324   0.317  0.144
# general    4963  0.324   0.320  0.141
# obc        5022  0.324   0.320  0.143
# sc         5001  0.322   0.319  0.141
# st         5081  0.325   0.320  0.143

# %%
plt.figure(figsize=(9, 5))

ax = sns.barplot(
    data=category_admission.reset_index(),
    x="category",
    y="mean",
    hue="category",
    palette="Set2",
    legend=False
)

plt.title(
    "Average Admission Probability by Category",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Category")
plt.ylabel("Average Admission Probability")

for container in ax.containers:
    ax.bar_label(container, fmt="%.3f")

plt.tight_layout()

plt.savefig(
    "../figures/category_vs_admission_probability.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The average admission probability is highly similar across all student categories, ranging from 0.322 to 0.325. ST has the highest average probability (0.325), while SC has the lowest (0.322). The very small differences suggest that student category has little practical association with average admission probability in this dataset.

# %% [markdown]
# ## State-wise Entrance Score Performance
#
# This analysis compares the average entrance examination score across states to identify geographical differences in recorded student performance.

# %%
state_performance = (
    df.groupby("state")["entrance_score"]
      .agg(["count", "mean", "median", "std"])
      .sort_values("mean", ascending=False)
      .round(2)
)

state_performance
# Out:
#                    count   mean  median     std
# state
# andhra pradesh       947  85.68    35.0  133.90
# goa                  890  83.87    18.5  135.08
# mizoram              955  82.67    24.0  128.76
# odisha               953  81.50    22.0  126.06
# arunachal pradesh    960  81.04    30.0  118.39
# chhattisgarh         981  80.06    24.0  121.58
# karnataka           1014  79.78    27.5  118.50
# bihar                949  79.67    22.0  119.98
# madhya pradesh       925  79.54    18.0  119.99
# rajasthan           1031  79.31    16.0  125.57
# tripura              942  78.67    20.0  118.42
# tamil nadu           976  77.95    20.0  118.82
# meghalaya            978  77.93    18.5  124.18
# gujarat             1008  77.93    24.0  118.33
# jharkhand            955  77.66    17.0  118.53
# manipur              939  77.10    20.0  119.50
# himachal pradesh     991  77.00    13.0  122.79
# kerala               888  75.63    21.0  115.15
# ...

# %%
plt.figure(figsize=(12, 8))

ax = sns.barplot(
    data=state_performance.reset_index(),
    x="mean",
    y="state",
    hue="state",
    palette="viridis",
    legend=False
)

plt.title(
    "Average Entrance Score by State",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Average Entrance Score")
plt.ylabel("State")

for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", padding=3)

plt.tight_layout()

plt.savefig(
    "../figures/state_wise_average_entrance_score.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The average entrance score varies across states. Andhra Pradesh has the highest average entrance score at 85.68, followed by Goa at 83.87 and Mizoram at 82.67. Telangana has the lowest average at 72.38, followed by Uttar Pradesh at 73.09. The difference between the highest and lowest state averages is approximately 13.30 points. Since the number of students represented by each state is relatively similar, the state-wise comparison provides a useful overview of geographical variation in recorded entrance scores. These differences indicate variation within the dataset but should not be interpreted as evidence that students from one state inherently perform better than another.

# %% [markdown]
# ## Entrance Score by Admission Status

# %%
plt.figure(figsize=(9, 6))

sns.boxplot(
    data=df,
    x="admission_status",
    y="entrance_score"
)

plt.title(
    "Entrance Score by Admission Status",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Admission Status")
plt.ylabel("Entrance Score")

plt.tight_layout()

plt.savefig(
    "../figures/entrance_score_by_admission_status.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The box plot shows a noticeable difference in entrance score distributions between admitted and rejected students. Admitted students have a substantially higher median entrance score, while rejected students are more concentrated toward lower scores. Both groups contain high-score observations, indicating that entrance score alone does not completely determine admission status. Overall, the distribution suggests that higher entrance scores are associated with a greater likelihood of admission in this dataset.

# %%
admission_score_summary = (
    df.groupby("admission_status")["entrance_score"]
      .agg(["count", "mean", "median", "std"])
      .round(2)
)

admission_score_summary
# Out:
#                   count    mean  median     std
# admission_status
# admitted           8152  106.92    57.0  147.87
# rejected          16848   63.83     4.0  101.54

# %% [markdown]
# ### Observation
#
# The numerical summary supports the pattern observed in the box plot. Admitted students have a higher mean entrance score (106.92) and median score (57.0) compared with rejected students, whose mean and median scores are 63.83 and 4.0 respectively. This indicates a strong difference in the distribution of entrance scores between the two admission-status groups. However, the considerable standard deviation within both groups shows that entrance score alone does not completely determine admission status.

# %% [markdown]
# ## Correlation Analysis
#
# Correlation analysis is used to examine the strength and direction of linear relationships between numerical variables. This helps identify which performance-related variables are most closely associated with admission probability.

# %%
# Select numerical variables
numerical_cols = [
    "age",
    "entrance_score",
    "board_percentage",
    "extracurricular_score",
    "admission_probability"
]

correlation_matrix = df[numerical_cols].corr().round(2)

correlation_matrix
# Out:
#                        age  entrance_score  board_percentage  \
# age                    1.0            0.00             -0.00
# entrance_score         0.0            1.00             -0.00
# board_percentage      -0.0           -0.00              1.00
# extracurricular_score -0.0            0.01              0.00
# admission_probability -0.0            0.55              0.73
#
#                        extracurricular_score  admission_probability
# age                                    -0.00                  -0.00
# entrance_score                          0.01                   0.55
# board_percentage                        0.00                   0.73
# extracurricular_score                   1.00                   0.40
# admission_probability                   0.40                   1.00

# %%
plt.figure(figsize=(9, 7))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5
)

plt.title(
    "Correlation Matrix of Numerical Variables",
    fontsize=16,
    fontweight="bold"
)

plt.tight_layout()

plt.savefig(
    "../figures/correlation_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ### Observation
#
# The correlation matrix shows that board percentage has the strongest positive relationship with admission probability, with a correlation of 0.73. Entrance score also has a moderate positive relationship with admission probability (0.55), while extracurricular score shows a weaker positive relationship (0.40). Age has almost no linear correlation with admission probability. These results indicate that academic performance variables are more strongly associated with admission probability than age in this dataset. Correlation indicates association and does not establish causation.

# %% [markdown]
# # Overall Findings
#
# The exploratory analysis of the NEET-JEE performance dataset revealed several important patterns:
#
# - The dataset contains 25,000 student records and 13 variables.
# - The dataset contains no missing values and no duplicate records.
# - Board percentage has the strongest positive correlation with admission probability (0.73).
# - Entrance score has a moderate positive correlation with admission probability (0.55).
# - Extracurricular score has a weaker positive relationship with admission probability (0.40).
# - Age has almost no linear relationship with admission probability.
# - Admitted students have higher entrance scores than rejected students.
# - Average entrance scores vary across states.
# - Admission probability is very similar across the student categories.
# - Among the analyzed entrance examinations, NEET has the highest average entrance score in this dataset.
#
# These findings provide an overall understanding of the factors associated with student performance and admission outcomes.

# %%
print("Final Dataset Shape:", df.shape)
print("Total Missing Values:", df.isnull().sum().sum())
print("Total Duplicate Rows:", df.duplicated().sum())
# Out:
# Final Dataset Shape: (25000, 13)
# Total Missing Values: 0
# Total Duplicate Rows: 0

# %% [markdown]
# ## Save Processed Dataset
#
# The dataset has been validated and contains no missing values or duplicate records. The cleaned dataset is now saved in the processed data folder for use in further analysis and reporting.

# %%
# Save the validated dataset

df.to_csv(
    "../data/processed/College_Admission_Cleaned.csv",
    index=False
)

print("Processed dataset saved successfully!")
# Out:
# Processed dataset saved successfully!
