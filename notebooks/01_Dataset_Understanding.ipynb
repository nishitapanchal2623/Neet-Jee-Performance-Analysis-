# %% [markdown]
# # Project 1: NEET-JEE Performance Analysis
#
# ## Phase 1: Dataset Understanding
#
# ---
#
# ### Objective
#
# The objective of this notebook is to understand the dataset before performing any preprocessing or exploratory data analysis (EDA). We will examine the dataset structure, inspect data types, identify missing values and duplicate records, and summarize the available features. This foundational analysis ensures a clear understanding of the data and supports reliable downstream analysis.
#
# ---

# %%
# ============================================================
# Import Required Libraries
# ============================================================

import pandas as pd
import numpy as np

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 # ============================================================
#       2 # Import Required Libraries
#       3 # ============================================================
#       4
# ----> 5 import pandas as pd
#       6 import numpy as np
#       7
#       8 # Display Settings
#
# ModuleNotFoundError: No module named 'pandas'
